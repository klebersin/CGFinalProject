# %%
import pyaudio
import wave
import speech_recognition as sr
import librosa, librosa.display
import matplotlib.pyplot as plt
import json
import os
import numpy as np
import math
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %%
SAMPLE_RATE = 44100
TRACK_DURATION = 30
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

def save_data(dataset_path, json_path, num_mfcc=13, n_fft=4096, hop_length=512, num_segments=7):
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }
    
    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)
    
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        if dirpath is not dataset_path:

            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            for f in filenames:
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                for d in range(num_segments):

                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
DATASET_PATH = "./Sounds"
JSON_PATH = "data.json"
save_data(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: elizabeth
# ./Sounds/elizabeth/eli (5).wav, segment:1
# ./Sounds/elizabeth/eli (5).wav, segment:2
# ./Sounds/elizabeth/eli (5).wav, segment:3
# ./Sounds/elizabeth/eli (5).wav, segment:4
# ./Sounds/elizabeth/eli (5).wav, segment:5
# ./Sounds/elizabeth/eli (5).wav, segment:6
# ./Sounds/elizabeth/eli (10).wav, segment:1
# ./Sounds/elizabeth/eli (10).wav, segment:2
# ./Sounds/elizabeth/eli (10).wav, segment:3
# ./Sounds/elizabeth/eli (10).wav, segment:4
# ./Sounds/elizabeth/eli (10).wav, segment:5
# ./Sounds/elizabeth/eli (10).wav, segment:6
# ./Sounds/elizabeth/eli (6).wav, segment:1
# ./Sounds/elizabeth/eli (6).wav, segment:2
# ./Sounds/elizabeth/eli (6).wav, segment:3
# ./Sounds/elizabeth/eli (6).wav, segment:4
# ./Sounds/elizabeth/eli (6).wav, segment:5
# ./Sounds/elizabeth/eli (6).wav, segment:6
# ./Sounds/elizabeth/eli (7).wav, segment:1
# ./Sounds/elizabeth/eli (7).wav, segment:2
# ./Sounds/elizabeth/eli (7).wav, segment:3
# ./Sounds/elizabeth/eli (7).wav, segment:4
# ./Sounds/elizabeth/eli (7).wav, segment:5
# ./Sounds/elizabeth/eli (7).wav, segment:6
# ./Sounds/elizabeth/eli.wav, segment:1
# ./Sounds/elizabeth/eli.wav, segment:2
# ./Sounds/elizabeth/eli.wav, segment:3
# ./Sounds/elizabeth/eli.wav, segment:4
# ./Sounds/elizabeth/eli.wav, segment:5
# ./Sounds/elizabeth/eli (3).wav, segment:1
# ./Sounds/elizabeth/eli (3).wav, segment:2
# ./Sounds/elizabeth/eli (3).wav, segment:3
# ./Sounds/elizabeth/eli (3).wav, segment:4
# ./Sounds/elizabeth/eli (3).wav, segment:5
# ./Sounds/elizabeth/eli (3).wav, segment:6
# ./Sounds/elizabeth/eli (2).wav, segment:1
# ./Sounds/elizabeth/eli (2).wav, segment:2
# ./Sounds/elizabeth/eli (2).wav, segment:3
# ./Sounds/elizabeth/eli (2).wav, segment:4
# ./Sounds/elizabeth/eli (2).wav, segment:5
# ./Sounds/elizabeth/eli (2).wav, segment:6
# ./Sounds/elizabeth/eli (11).wav, segment:1
# ./Sounds/elizabeth/eli (11).wav, segment:2
# ./Sounds/elizabeth/eli (11).wav, segment:3
# ./Sounds/elizabeth/eli (11).wav, segment:4
# ./Sounds/elizabeth/eli (11).wav, segment:5
# ./Sounds/elizabeth/eli (11).wav, segment:6
# ./Sounds/elizabeth/eli (9).wav, segment:1
# ./Sounds/elizabeth/eli (9).wav, segment:2
# ./Sounds/elizabeth/eli (9).wav, segment:3
# ./Sounds/elizabeth/eli (9).wav, segment:4
# ./Sounds/elizabeth/eli (9).wav, segment:5
# ./Sounds/elizabeth/eli (9).wav, segment:6
# ./Sounds/elizabeth/eli (8).wav, segment:1
# ./Sounds/elizabeth/eli (8).wav, segment:2
# ./Sounds/elizabeth/eli (8).wav, segment:3
# ./Sounds/elizabeth/eli (8).wav, segment:4
# ./Sounds/elizabeth/eli (8).wav, segment:5
# ./Sounds/elizabeth/eli (8).wav, segment:6
# ./Sounds/elizabeth/eli (4).wav, segment:1
# ./Sounds/elizabeth/eli (4).wav, segment:2
# ./Sounds/elizabeth/eli (4).wav, segment:3
# ./Sounds/elizabeth/eli (4).wav, segment:4
# ./Sounds/elizabeth/eli (4).wav, segment:5
# ./Sounds/elizabeth/eli (4).wav, segment:6
#
# Processing: kleber
# ./Sounds/kleber/kleber (4).wav, segment:1
# ./Sounds/kleber/kleber (4).wav, segment:2
# ./Sounds/kleber/kleber (4).wav, segment:3
# ./Sounds/kleber/kleber (4).wav, segment:4
# ./Sounds/kleber/kleber (4).wav, segment:5
# ./Sounds/kleber/kleber (4).wav, segment:6
# ./Sounds/kleber/kleber (2).wav, segment:1
# ./Sounds/kleber/kleber (2).wav, segment:2
# ./Sounds/kleber/kleber (2).wav, segment:3
# ./Sounds/kleber/kleber (2).wav, segment:4
# ./Sounds/kleber/kleber (2).wav, segment:5
# ./Sounds/kleber/kleber (2).wav, segment:6
# ./Sounds/kleber/kleber (5).wav, segment:1
# ./Sounds/kleber/kleber (5).wav, segment:2
# ./Sounds/kleber/kleber (5).wav, segment:3
# ./Sounds/kleber/kleber (5).wav, segment:4
# ./Sounds/kleber/kleber (5).wav, segment:5
# ./Sounds/kleber/kleber (5).wav, segment:6
# ./Sounds/kleber/kleber (6).wav, segment:1
# ./Sounds/kleber/kleber (6).wav, segment:2
# ./Sounds/kleber/kleber (6).wav, segment:3
# ./Sounds/kleber/kleber (6).wav, segment:4
# ./Sounds/kleber/kleber (6).wav, segment:5
# ./Sounds/kleber/kleber (6).wav, segment:6
# ./Sounds/kleber/kleber (3).wav, segment:1
# ./Sounds/kleber/kleber (3).wav, segment:2
# ./Sounds/kleber/kleber (3).wav, segment:3
# ./Sounds/kleber/kleber (3).wav, segment:4
# ./Sounds/kleber/kleber (3).wav, segment:5
# ./Sounds/kleber/kleber (3).wav, segment:6
# ./Sounds/kleber/kleber (8).wav, segment:1
# ./Sounds/kleber/kleber (8).wav, segment:2
# ./Sounds/kleber/kleber (8).wav, segment:3
# ./Sounds/kleber/kleber (8).wav, segment:4
# ./Sounds/kleber/kleber (8).wav, segment:5
# ./Sounds/kleber/kleber (8).wav, segment:6
#
# Processing: franco
# ./Sounds/franco/franco (4).wav, segment:1
# ./Sounds/franco/franco (4).wav, segment:2
# ./Sounds/franco/franco (4).wav, segment:3
# ./Sounds/franco/franco (4).wav, segment:4
# ./Sounds/franco/franco (4).wav, segment:5
# ./Sounds/franco/franco (4).wav, segment:6
# ./Sounds/franco/franco (2).wav, segment:1
# ./Sounds/franco/franco (2).wav, segment:2
# ./Sounds/franco/franco (2).wav, segment:3
# ./Sounds/franco/franco (2).wav, segment:4
# ./Sounds/franco/franco (2).wav, segment:5
# ./Sounds/franco/franco (2).wav, segment:6
# ./Sounds/franco/franco (3).wav, segment:1
# ./Sounds/franco/franco (3).wav, segment:2
# ./Sounds/franco/franco (3).wav, segment:3
# ./Sounds/franco/franco (3).wav, segment:4
# ./Sounds/franco/franco (3).wav, segment:5
# ./Sounds/franco/franco (3).wav, segment:6
# ./Sounds/franco/franco.wav, segment:1
# ./Sounds/franco/franco.wav, segment:2
# ./Sounds/franco/franco.wav, segment:3
# ./Sounds/franco/franco.wav, segment:4
# ./Sounds/franco/franco.wav, segment:5
# ./Sounds/franco/franco.wav, segment:6
# ./Sounds/franco/franco (8).wav, segment:1
# ./Sounds/franco/franco (8).wav, segment:2
# ./Sounds/franco/franco (8).wav, segment:3
# ./Sounds/franco/franco (8).wav, segment:4
# ./Sounds/franco/franco (8).wav, segment:5
# ./Sounds/franco/franco (8).wav, segment:6
# ./Sounds/franco/franco (6).wav, segment:1
# ./Sounds/franco/franco (6).wav, segment:2
# ./Sounds/franco/franco (6).wav, segment:3
# ./Sounds/franco/franco (6).wav, segment:4
# ./Sounds/franco/franco (6).wav, segment:5
# ./Sounds/franco/franco (6).wav, segment:6
# ./Sounds/franco/franco (5).wav, segment:1
# ./Sounds/franco/franco (5).wav, segment:2
# ./Sounds/franco/franco (5).wav, segment:3
# ./Sounds/franco/franco (5).wav, segment:4
# ./Sounds/franco/franco (5).wav, segment:5
# ./Sounds/franco/franco (5).wav, segment:6
# ./Sounds/franco/franco (7).wav, segment:1
# ./Sounds/franco/franco (7).wav, segment:2
# ./Sounds/franco/franco (7).wav, segment:3
# ./Sounds/franco/franco (7).wav, segment:4
# ./Sounds/franco/franco (7).wav, segment:5
# ./Sounds/franco/franco (7).wav, segment:6

# %%
def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
if __name__ == "__main__":
    DATA_PATH = "data.json"
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    model = keras.Sequential([

        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        keras.layers.Dense(3, activation='softmax')
    ])

    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100)
# Out:
# Data succesfully loaded!
# Epoch 1/100
# 4/4 [==============================] - 0s 51ms/step - loss: 116.0205 - accuracy: 0.3173 - val_loss: 43.7686 - val_accuracy: 0.4444
# Epoch 2/100
# 4/4 [==============================] - 0s 30ms/step - loss: 78.4644 - accuracy: 0.3462 - val_loss: 42.7657 - val_accuracy: 0.4222
# Epoch 3/100
# 4/4 [==============================] - 0s 33ms/step - loss: 62.9991 - accuracy: 0.3750 - val_loss: 24.3210 - val_accuracy: 0.4444
# Epoch 4/100
# 4/4 [==============================] - 0s 37ms/step - loss: 57.5982 - accuracy: 0.4519 - val_loss: 21.6950 - val_accuracy: 0.4667
# Epoch 5/100
# 4/4 [==============================] - 0s 33ms/step - loss: 46.2100 - accuracy: 0.4904 - val_loss: 12.0578 - val_accuracy: 0.6222
# Epoch 6/100
# 4/4 [==============================] - 0s 31ms/step - loss: 38.3082 - accuracy: 0.4712 - val_loss: 5.9718 - val_accuracy: 0.7556
# Epoch 7/100
# 4/4 [==============================] - 0s 32ms/step - loss: 34.0858 - accuracy: 0.5000 - val_loss: 5.6434 - val_accuracy: 0.6889
# Epoch 8/100
# 4/4 [==============================] - 0s 37ms/step - loss: 24.4856 - accuracy: 0.5288 - val_loss: 3.8036 - val_accuracy: 0.7111
# Epoch 9/100
# 4/4 [==============================] - 0s 34ms/step - loss: 21.6457 - accuracy: 0.5192 - val_loss: 4.4477 - val_accuracy: 0.7111
# Epoch 10/100
# 4/4 [==============================] - 0s 30ms/step - loss: 33.0175 - accuracy: 0.5192 - val_loss: 7.4063 - val_accuracy: 0.6667
# Epoch 11/100
# 4/4 [==============================] - 0s 31ms/step - loss: 15.2199 - accuracy: 0.6442 - val_loss: 7.2253 - val_accuracy: 0.6444
# Epoch 12/100
# 4/4 [==============================] - 0s 30ms/step - loss: 24.1179 - accuracy: 0.5865 - val_loss: 4.7252 - val_accuracy: 0.6889
# Epoch 13/100
# 4/4 [==============================] - 0s 30ms/step - loss: 24.2659 - accuracy: 0.5481 - val_loss: 3.6540 - val_accuracy: 0.8444
# Epoch 14/100
# 4/4 [==============================] - 0s 30ms/step - loss: 19.5034 - accuracy: 0.6154 - val_loss: 3.8042 - val_accuracy: 0.7778
# Epoch 15/100
# 4/4 [==============================] - 0s 30ms/step - loss: 17.5011 - accuracy: 0.5385 - val_loss: 1.7819 - val_accuracy: 0.8444
# Epoch 16/100
# 4/4 [==============================] - 0s 32ms/step - loss: 18.8317 - accuracy: 0.5962 - val_loss: 2.3470 - val_accuracy: 0.8000
100
# 4/4 [==============================] - 0s 27ms/step - loss: 2.3093 - accuracy: 0.9519 - val_loss: 1.1228 - val_accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 35ms/step - loss: 2.0917 - accuracy: 0.9231 - val_loss: 1.1260 - val_accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 27ms/step - loss: 2.3235 - accuracy: 0.9519 - val_loss: 1.1232 - val_accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 27ms/step - loss: 1.9187 - accuracy: 0.9423 - val_loss: 1.1205 - val_accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 33ms/step - loss: 1.8012 - accuracy: 0.9615 - val_loss: 1.1198 - val_accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 27ms/step - loss: 1.3681 - accuracy: 0.9808 - val_loss: 1.1198 - val_accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 27ms/step - loss: 1.5457 - accuracy: 0.9615 - val_loss: 1.1860 - val_accuracy: 0.9778
# Epoch 88/100
# 4/4 [==============================] - 0s 36ms/step - loss: 1.7956 - accuracy: 0.9519 - val_loss: 1.4902 - val_accuracy: 0.9556
# Epoch 89/100
# 4/4 [==============================] - 0s 29ms/step - loss: 2.2221 - accuracy: 0.9327 - val_loss: 1.2589 - val_accuracy: 0.9556
# Epoch 90/100
# 4/4 [==============================] - 0s 27ms/step - loss: 2.0878 - accuracy: 0.9327 - val_loss: 1.1168 - val_accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 33ms/step - loss: 1.7626 - accuracy: 0.9712 - val_loss: 1.2306 - val_accuracy: 0.9778
# Epoch 92/100
# 4/4 [==============================] - 0s 32ms/step - loss: 2.1448 - accuracy: 0.9327 - val_loss: 1.6447 - val_accuracy: 0.9333
# Epoch 93/100
# 4/4 [==============================] - 0s 26ms/step - loss: 2.0613 - accuracy: 0.9519 - val_loss: 1.1958 - val_accuracy: 0.9778
# Epoch 94/100
# 4/4 [==============================] - 0s 35ms/step - loss: 1.9849 - accuracy: 0.9423 - val_loss: 1.4119 - val_accuracy: 0.9556
# Epoch 95/100
# 4/4 [==============================] - 0s 31ms/step - loss: 1.4177 - accuracy: 0.9519 - val_loss: 1.8686 - val_accuracy: 0.9556
# Epoch 96/100
# 4/4 [==============================] - 0s 28ms/step - loss: 1.8399 - accuracy: 0.9712 - val_loss: 1.5794 - val_accuracy: 0.9778
# Epoch 97/100
# 4/4 [==============================] - 0s 29ms/step - loss: 1.8765 - accuracy: 0.9712 - val_loss: 1.1773 - val_accuracy: 0.9778
# Epoch 98/100
# 4/4 [==============================] - 0s 31ms/step - loss: 1.6027 - accuracy: 0.9712 - val_loss: 1.1398 - val_accuracy: 0.9778
# Epoch 99/100
# 4/4 [==============================] - 0s 28ms/step - loss: 2.0830 - accuracy: 0.9615 - val_loss: 1.1481 - val_accuracy: 0.9778
# Epoch 100/100
# 4/4 [==============================] - 0s 27ms/step - loss: 1.6919 - accuracy: 0.9615 - val_loss: 1.3978 - val_accuracy: 0.9111

# %%
test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 2/2 - 0s - loss: 1.3978 - accuracy: 0.9111
#
# Test accuracy: 0.9111111164093018

# %%
duracion = 5
archivo = "audio.wav"
audio=pyaudio.PyAudio()
FORMAT=pyaudio.paInt16
CHANNELS=2
RATE=44100
CHUNK=1024

# %%
def grabar():
    stream=audio.open(format=FORMAT, channels=CHANNELS, rate = RATE, input=True,frames_per_buffer=CHUNK)
    print("Grabando ...")
    frames=[]

    for i in range(0,int(44100/1024*duracion)):
        data=stream.read(1024)
        frames.append(data)

    print("Grabacion a terminado ")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    waveFile=wave.open(archivo,'wb')
    waveFile.setnchannels(2)
    waveFile.setsampwidth(audio.get_sample_size(pyaudio.paInt16))
    waveFile.setframerate(44100)
    waveFile.writeframes(b''.join(frames))
    waveFile.close()

# %%
grabar()
# Out:
# Grabando ...
# Grabacion a terminado

# %%
def formatFile(archivo):
    signal, sample_rate = librosa.load(archivo, sr=44100)
    mfcc = librosa.feature.mfcc(signal, sample_rate, n_mfcc=13, n_fft=4096, hop_length=512)
    mfcc = mfcc.T
    topredict = np.array(mfcc.tolist())
    topredict = np.expand_dims(topredict, axis=0)
    return topredict

# %%
signal, sample_rate = librosa.load(archivo, sr=44100)
librosa.display.waveplot(signal, sample_rate, alpha=0.4)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
signal, sample_rate = librosa.load(archivo, sr=44100)

mfcc = librosa.feature.mfcc(signal, sample_rate, n_mfcc=13, n_fft=4096, hop_length=512)
librosa.display.specshow(mfcc, sr=sample_rate, hop_length=512)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")

plt.show()

# %%
mfcc = mfcc.T
topredict = np.array(mfcc.tolist())
topredict = np.expand_dims(topredict, axis=0)
topredict.shape
# Out:
# (1, 431, 13)

# %%
predictions = model.predict(X_test)
user = np.argmax(predictions[2])
predictions
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 1.0011649e-36],
#        [1.0000000e+00, 0.0000000e+00, 3.5246459e-13],
#        [9.3848438e-18, 0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 6.1074963e-30],
#        [2.5658613e-01, 5.0055827e-03, 7.3840833e-01],
#        [1.0000000e+00, 6.6901415e-37, 5.3133498e-09],
#        [1.0000000e+00, 0.0000000e+00, 6.1719991e-37],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 3.8995610e-35, 2.8214933e-14],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [6.8496673e-05, 1.3734338e-01, 8.6258811e-01],
#        [0.0000000e+00, 1.0000000e+00, 2.5358548e-22],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 2.0964823e-23],
#        [1.0000000e+00, 0.0000000e+00, 2.2809077e-15],
#        [1.0000000e+00, 0.0000000e+00, 2.5676143e-24],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [9.3893081e-01, 7.5723721e-24, 6.1069164e-02],
#        [1.0000000e+00, 0.0000000e+00, 9.2053569e-34],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [1.7246130e-36, 1.0000000e+00, 4.4733391e-29],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 8.0062119e-33],
#        [2.0861998e-37, 0.0000000e+00, 1.0000000e+00],
#        [1.8198030e-07, 0.0000000e+00, 9.9999976e-01],
#        [2.0510613e-26, 5.8902670e-02, 9.4109726e-01],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [1.1710314e-33, 0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 2.1022366e-19],
#        [1.8517702e-23, 1.0000000e+00, 1.3902479e-13],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.0027024e-34, 1.3319584e-10],
#        [3.9197031e-31, 0.0000000e+00, 1.0000000e+00],
#        [1.3881638e-19, 0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 4.8548634e-11],
#        [1.0000000e+00, 0.0000000e+00, 2.1022366e-19],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [2.3209253e-35, 1.0000000e+00, 7.8231273e-35],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [2.0136657e-34, 0.0000000e+00, 1.0000000e+00],
#        [2.3009694e-33, 1.0000000e+00, 1.8838631e-21],
#        [1.0000000e+00, 0.0000000e+00, 9.3046794e-13],
#        [1.3606853e-20, 1.0000000e+00, 2.5687559e-20],
#        [6.3913314e-22, 0.0000000e+00, 1.0000000e+00]], dtype=float32)

# %%
from main import Controller
Controller(model)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 431, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, 431, 13), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (None, 173, 13).
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/kleber/anaconda3/lib/python3.8/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/home/kleber/Computación gráfica/main.py", line 75, in recognizer
#     self.myModel.predict(self.topredict)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1751, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 885, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3038, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3459, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3381, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3298, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1007, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 668, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 994, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:1586 predict_function  *
#         return step_function(self, iterator)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:1576 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:1569 run_step  **
#         outputs = model.predict_step(data)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:1537 predict_step
#         return self(x, training=False)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py:1037 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/sequential.py:369 call
#         return super(Sequential, self).call(inputs, training=training, mask=mask)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py:414 call
#         return self._run_internal_graph(
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py:550 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/kleber/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py:250 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer dense_8 is incompatible with the layer: expected axis -1 of input shape to have value 5603 but received input with shape (None, 2249)
